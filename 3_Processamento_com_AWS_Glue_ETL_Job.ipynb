# %% [markdown]
# **Terceira Atividade da Disciplina Gerenciamento de Big Data**
#
# Discente: Valéria Cristina Andrade Rodrigues de Figueredo

# %% [markdown]
# # **Processamento com AWS Glue ETL Job**

# %% [markdown]
# # **1. Visual ETL**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **2. Input**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **3. Change Schema**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **4. Output**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **5. Job Runs**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **6. Resultado no Amazon s3**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **7. Data Catalog**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **8. Resultado no Athena**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
