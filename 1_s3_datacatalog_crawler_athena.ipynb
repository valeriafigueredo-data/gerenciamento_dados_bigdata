# %% [markdown]
# **Atividade da Primeira Semana da Disciplina - Gerenciamento de Dados para Big Data**
#
# **Discente: Valéria Cristina A.R. de Figueredo**
#
# **Objetivos**: Processar os dados com linguagem python, armazená-los no bucket da AWS -S3, catalogá-los via  AWS Glue Data Catalog e  AWS Glue Crawler e analisar e responder as questões no Athena, com queries SQL.

# %% [markdown]
# # **1. Importando Dados**

# %%
from google.colab import files

# Faça upload do(s) arquivo(s) CSV
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d22e3297-aacb-43eb-a7f3-4c3c327daa73" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d22e3297-aacb-43eb-a7f3-4c3c327daa73">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # **2. Pré-Processamento dos dados**

# %%
import pandas as pd

# Substitua pelo nome do arquivo que você subiu
nome_arquivo = 'file1.csv'

# Ler o CSV (tenta automaticamente detectar o separador, mas geralmente é vírgula)
df = pd.read_csv(nome_arquivo)

# Visualizar os primeiros registros
df.head()
# Out:
#    year             player nationality
# 0  2019       Lionel Messi   Argentina
# 1  2018        Luka Modrić     Croatia
# 2  2017  Cristiano Ronaldo    Portugal
# 3  2016  Cristiano Ronaldo    Portugal
# 4  2015       Lionel Messi   Argentina

# %%
import pandas as pd

# Lê o CSV pulando a primeira linha (header é a segunda linha do arquivo)
df = pd.read_csv(nome_arquivo, skiprows=1)

# Visualizar os dados limpos
df.head()
# Out:
#    year             player nationality
# 0  2019       Lionel Messi   Argentina
# 1  2018        Luka Modrić     Croatia
# 2  2017  Cristiano Ronaldo    Portugal
# 3  2016  Cristiano Ronaldo    Portugal
# 4  2015       Lionel Messi   Argentina

# %%
# Salvar o DataFrame limpo como novo CSV
df.to_csv('file1.0.csv', index=False)

# Baixar o novo arquivo limpo
from google.colab import files
files.download('file1.0.csv')

# %% [markdown]
# # **3. Armazenamento em Buckets - S3**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **4. Análise dos Dados - Athenas - com Queries SQL**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **4. 1 Questões**

# %% [markdown]
# # **Primeira Questão**

# %% [markdown]
# **● Quais os 10 jogadores que mais ganharam o prêmio de melhor jogador do mundo FIFA?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Segunda Questão**

# %% [markdown]
# **● Qual país tem mais jogadores que ganharam o prêmio de melhor jogador do mundo FIFA? Quantos prêmios cada país têm?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Terceira Questão**

# %% [markdown]
# **Qual equipe marcou mais gols na Premier League (18/19) como mandante?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #***Quarta Questão***

# %% [markdown]
# **● Qual equipe teve a pior defesa na Premier League (18/19) como visitante?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Quinta Questão**

# %% [markdown]
# **● Qual jogo da Premier League (18/19) teve maior goleada do mandante?Diferença de gols feitos e recebidos?**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
